# %%
# %run -i "feature_extraction.py"

# %%
# %run -i "neural_network.py"
# Out:
# Shapes:
# (7165, 23, 520)
# (7165, 23)
# (7165,)
# [0 1 2 3 4 5]
# epoch:  0
# epoch:  1
# epoch:  2
# epoch:  3
# epoch:  4
# molecule
# Target:  tensor([[-1131.6400]])
# Our_vl:  tensor([[-3.4223e+15]], grad_fn=<AddBackward0>)
# Loss  :  tensor(1.1712e+31, grad_fn=<MseLossBackward>)
# molecule
# Target:  tensor([[-1317.0800]])
# Our_vl:  tensor([[-2.9731e+15]], grad_fn=<AddBackward0>)
# Loss  :  tensor(8.8395e+30, grad_fn=<MseLossBackward>)
# molecule
# Target:  tensor([[-1343.7600]])
# Our_vl:  tensor([[-2.9731e+15]], grad_fn=<AddBackward0>)
# Loss  :  tensor(8.8395e+30, grad_fn=<MseLossBackward>)
# molecule
# Target:  tensor([[-1124.1500]])
# Our_vl:  tensor([[-2.4665e+15]], grad_fn=<AddBackward0>)
# Loss  :  tensor(6.0836e+30, grad_fn=<MseLossBackward>)
# molecule
# Target:  tensor([[-1353.0200]])
# Our_vl:  tensor([[-5.2758e+14]], grad_fn=<AddBackward0>)
# Loss  :  tensor(2.7834e+29, grad_fn=<MseLossBackward>)
# molecule
# Target:  tensor([[-1750.7400]])
# ...
